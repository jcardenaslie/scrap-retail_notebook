# %%
import requests
from bs4 import BeautifulSoup

# %%
html = requests.get("https://www.sodimac.cl/sodimac-homy/search?Ntt=cama").text
soup = BeautifulSoup(html, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find_all()
