# %%
import requests
from bs4 import BeautifulSoup
import datetime
import pandas as pd
import re

# %%
def scrap(url):
    html = requests.get(url).text
    soup = BeautifulSoup(html, "lxml")
    
    if soup is None:
        return None
    
    return soup

def extractProduct(product_div):
    
    if product_div is None:
        return None

    product = dict()

    product['sku'] = product_div["data-key"]
    product['marca'] = product_div.find("div", {"class":"product-brand"}).text
    product['nombre'] = product_div.find("h2", {"class":"product-title"}).text
    product['precio'] = int("".join(re.findall(r'\d', product_div.find("div", {"class":"price"}).text)))
    product['imagen'] = product_div.find("a", {"class":"link-primary"}).div.img["src"]
    product['url'] = "www.sodimac.cl" + product_div.find("a", {"class":"link-primary"})['href']
    product['time'] = datetime.datetime.now()
    
    return product

# %%
search_term = "comoda"
base_url = "https://www.sodimac.cl/sodimac-homy/search?Ntt=" + search_term

url = base_url

products = list()

for page in range(1,1000):
    if page > 1:
        url = base_url + "&currentpage=" + str(page)
        
    print("Scrapping: " + url)
        
    soup = scrap(url)
    
    elements = soup.findAll("div", {"class": "product-wrapper"})
    
    if len(elements) <= 0:
        break
    
    products.extend([ extractProduct(i) for i in elements])
    
print("Total scraped products: ", len(products))
# Out:
# Scrapping: https://www.sodimac.cl/sodimac-homy/search?Ntt=comoda
# 28
# Scrapping: https://www.sodimac.cl/sodimac-homy/search?Ntt=comoda&currentpage=2
# 28
# Scrapping: https://www.sodimac.cl/sodimac-homy/search?Ntt=comoda&currentpage=3
# 28
# Scrapping: https://www.sodimac.cl/sodimac-homy/search?Ntt=comoda&currentpage=4
# 28
# Scrapping: https://www.sodimac.cl/sodimac-homy/search?Ntt=comoda&currentpage=5
# 28
# Scrapping: https://www.sodimac.cl/sodimac-homy/search?Ntt=comoda&currentpage=6
# 28
# Scrapping: https://www.sodimac.cl/sodimac-homy/search?Ntt=comoda&currentpage=7
# 27
# Scrapping: https://www.sodimac.cl/sodimac-homy/search?Ntt=comoda&currentpage=8
# 0
# 195

# %%
df = pd.DataFrame(products)
df
# Out:
#          sku         marca                                   nombre  precio  \
# 0    4025695  Meya Muebles                            Cómoda taiwan  400990
# 1    4025660  Meya Muebles                              Cómoda bali  680990
# 2    363888X       Medular                            Comoda cherry  215990
# 3    4227204      Kidscool                     Cómoda 40x61c85,5 cm   69990
# 4    537653X      Kidscool                 Cómoda 77x93x46 cm menta  109990
# ..       ...           ...                                      ...     ...
# 190  3048357          Homy              Tocador 42x90x142 cm Blanco  139990
# 191  3855589   Tecnomobili    Tocador 2 cajones 48x36x175 cm Blanco  109990
# 192  3048365          Homy       Tocador triple 40x90x145 cm blanco  139990
# 193  2733951        Tvilum        Zapatera 5 cajones 71x20x181  oak   99990
# 194  3155064        Tvilum  Zapatera 3 cajones 77x24x131 blanco/oak   79990
#
#                                                 imagen  \
# 0    https://sodimac.scene7.com/is/image//SodimacCL...
# 1    https://sodimac.scene7.com/is/image//SodimacCL...
# 2    https://sodimac.scene7.com/is/image//SodimacCL...
# 3    https://sodimac.scene7.com/is/image//SodimacCL...
# 4    https://sodimac.scene7.com/is/image//SodimacCL...
# ..                                                 ...
# 190  https://sodimac.scene7.com/is/image//SodimacCL...
# 191  https://sodimac.scene7.com/is/image//SodimacCL...
# 192  https://sodimac.scene7.com/is/image//SodimacCL...
# 193  https://sodimac.scene7.com/is/image//SodimacCL...
# 194  https://sodimac.scene7.com/is/image//SodimacCL...
#
#                                                    url  \
# 0    www.sodimac.cl/sodimac-homy/product/4025695/Co...
# 1    www.sodimac.cl/sodimac-homy/product/4025660/Co...
# 2    www.sodimac.cl/sodimac-homy/product/363888X/Co...
# 3    www.sodimac.cl/sodimac-homy/product/4227204/Co...
# 4    www.sodimac.cl/sodimac-homy/product/537653X/Co...
# ..                                                 ...
# 190  www.sodimac.cl/sodimac-homy/product/3048357/To...
# 191  www.sodimac.cl/sodimac-homy/product/3855589/To...
# 192  www.sodimac.cl/sodimac-homy/product/3048365/To...
# 193  www.sodimac.cl/sodimac-homy/product/2733951/Za...
# 194  www.sodimac.cl/sodimac-homy/product/3155064/Za...
#
#                           time
# 0   2020-03-14 21:07:31.415617
# 1   2020-03-14 21:07:31.416615
# 2   2020-03-14 21:07:31.417615
# 3   2020-03-14 21:07:31.418615
# 4   2020-03-14 21:07:31.420614
# ..                         ...
# 190 2020-03-14 21:07:36.421677
# 191 2020-03-14 21:07:36.421677
# 192 2020-03-14 21:07:36.422676
# 193 2020-03-14 21:07:36.423676
# 194 2020-03-14 21:07:36.424676
#
# [195 rows x 7 columns]

# %%
df.describe()
# Out:
#               precio
# count     195.000000
# mean   159235.128205
# std    101600.740750
# min     10990.000000
# 25%     87990.000000
# 50%    129990.000000
# 75%    212490.000000
# max    680990.000000

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [sku, marca, nombre, precio, imagen, url, time]
# Index: []
